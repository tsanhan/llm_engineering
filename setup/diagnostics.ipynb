# %% [markdown]
# # Gathering Essential Diagnostic information
#
# ## Please run this next cell to gather some important data
#
# Please run the next cell; it should take a minute or so to run (mostly the network test).
# Then email me the output of the last cell to ed@edwarddonner.com.
# Alternatively: this will create a file called report.txt - just attach the file to your email.

# %%
# Run my diagnostics report to collect key information for debugging
# Please email me the results. Either copy & paste the output, or attach the file report.txt

# !pip install -q requests speedtest-cli psutil setuptools
from diagnostics import Diagnostics
Diagnostics().run()
# Out:
#   WARNING: The scripts speedtest-cli.exe and speedtest.exe are installed in 'C:\Users\tsanh\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'C:\Users\tsanh\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Python313\python.exe -m pip install --upgrade pip
# Starting diagnostics at 2026-09-18 16:22:06
#
# ===== System Information =====
# Operating System: Windows
# Windows Release: 11
# Windows Version: 10.0.26200
# Architecture: ('64bit', 'WindowsPE')
# Machine: AMD64
# Processor: Intel64 Family 6 Model 141 Stepping 1, GenuineIntel
# Total RAM: 15.73 GB
# Available RAM: 4.57 GB
# Free Disk Space: 480.34 GB
#
# ===== File System Information =====
# Current Directory: c:\Users\tsanh\Projects\OneDrive\Projects\llm_engineering\setup
# Write permission: OK
#
# Files in Current Directory:
#  - SETUP-new.md
#  - __pycache__
#  - diagnostics.ipynb
#  - diagnostics.py
#  - report.txt
#  - troubleshooting.ipynb
#
# ===== Git Repository Information =====
# Git Repository Root: C:/Users/tsanh/Projects/OneDrive/Projects/llm_engineering
# Current Commit: 0812ea5dbdb0fd95328468e6a3f6f107cad9d2f7
# Remote Origin: https://github.com/tsanhan/llm_engineering.git
#
# ===== Environment File Check =====
# WARNING: .env file not found in project root
#
# ===== Anaconda Environment Check =====
# No active Anaconda environment detected
#
# ===== Virtualenv Check =====
# Virtualenv is active:
# Environment Path: C:\Users\tsanh\Projects\OneDrive\Projects\llm_engineering\.venv
# Environment Name: .venv
#
# Python Environment:
# Python Version: 3.12.12 (main, Feb 12 2026, 00:40:26) [MSC v.1944 64 bit (AMD64)]
# Python Executable: c:\Users\tsanh\Projects\OneDrive\Projects\llm_engineering\.venv\Scripts\python.exe
# c:\Users\tsanh\Projects\OneDrive\Projects\llm_engineering\setup\diagnostics.py:255: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Required Package Versions:
# openai: 2.7.1
# python-dotenv: 1.2.1
# requests: 2.32.5
# gradio: 5.49.1
# transformers: 4.57.1
#
# ===== Network Connectivity Check =====
# SSL Version: OpenSSL 3.5.5 27 Jan 2026
# ✓ Connected to https://www.google.com
#   Response time: 0.53s
#
# Performing bandwidth test using speedtest-cli...
# Download speed: 0.85 Mbps
# Upload speed: 3.00 Mbps
# WARNING: Download speed is low
#
# ===== Environment Variables Check =====
#
# PYTHONPATH is not set.
#
# Python sys.path:
#  - C:\Users\tsanh\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\python312.zip
#  - C:\Users\tsanh\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\DLLs
#  - C:\Users\tsanh\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib
#  - C:\Users\tsanh\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none
#  - c:\Users\tsanh\Projects\OneDrive\Projects\llm_engineering\.venv
#  -
#  - c:\Users\tsanh\Projects\OneDrive\Projects\llm_engineering\.venv\Lib\site-packages
#  - c:\Users\tsanh\Projects\OneDrive\Projects\llm_engineering\.venv\Lib\site-packages\setuptools\_vendor
# WARNING: OPENAI_API_KEY environment variable is not set after calling load_dotenv()
#
# ===== Additional Diagnostics =====
# Temp directory is writable: C:\Users\tsanh\AppData\Local\Temp
#
# ===== Warnings Found =====
# The following warnings were detected. They might not prevent the program from running but could cause unexpected behavior:
# - .env file not found in project root
# - Download speed is low
# - OPENAI_API_KEY environment variable is not set after calling load_dotenv()
#
#
# Completed diagnostics at 2026-09-18 16:22:46
#
#
# Please send these diagnostics to me at ed@edwarddonner.com
# Either copy & paste the above output into an email, or attach the file report.txt that has been created in this directory.
